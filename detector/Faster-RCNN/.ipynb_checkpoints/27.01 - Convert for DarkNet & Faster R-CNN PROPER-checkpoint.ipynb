# %%
import numpy as np
import pandas as pd
import os
import glob
import time
import cv2

from sklearn.preprocessing import LabelEncoder

# %%
label_path = '/home/w/DS_Projects/Kaggle/Nature Conservancy/Scripts/Bounding Boxes/Liu Weijie/'
data_path = '/home/w/DS_Projects/Kaggle/Nature Conservancy/train/'

labels = ['ALB', 'BET', 'DOL', 'LAG', 'NoF', 'OTHER', 'SHARK', 'YFT']

label_files = [label_path + '{}.json'.format(labels[0]), label_path + '{}.json'.format(labels[1]),
               label_path + '{}.json'.format(labels[2]), label_path + '{}.json'.format(labels[3]),
               label_path + '{}.json'.format(labels[5]), label_path + '{}.json'.format(labels[6]),
               label_path + '{}.json'.format(labels[7])]


data_dirs = [data_path + '{}/'.format(labels[0]), data_path + '{}/'.format(labels[1]), 
             data_path + '{}/'.format(labels[2]), data_path + '{}/'.format(labels[3]),
             data_path + '{}/'.format(labels[5]), data_path + '{}/'.format(labels[6]),
             data_path + '{}/'.format(labels[7])]

# %%
def to_df():
    
    dfs = []
    for i in range(len(label_files)):
        df = pd.read_json(label_files[i])
        dfs.append(df)
    
    filenames = []
    short_filenames = []
    classes = []
    xs = []
    ys = []
    heights = []
    widths = []
    shapes = []

    for df in dfs:
        for file in range(len(df)):
            num_annots = len(df.iloc[file, :]['annotations'])
            for i in range(num_annots):
                
                filenames.append(data_path + df.iloc[file, :]['filename'])
                short_filenames.append(df.iloc[file, :]['filename'])
                shapes.append(cv2.imread(data_path + df.iloc[file, :]['filename']).shape)
                xs.append(df.iloc[file, :]['annotations'][i]['x'])
                ys.append(df.iloc[file, :]['annotations'][i]['y'])
                heights.append(df.iloc[file, :]['annotations'][i]['height'])
                widths.append(df.iloc[file, :]['annotations'][i]['width'])
                classes.append(df.iloc[file, :]['annotations'][i]['class'])
                

    print(len(filenames))
    print(len(classes))
    print(len(xs))
    print(len(ys))
    print(len(heights))
    print(len(widths))

    filenames = pd.DataFrame(filenames)
    short_filenames = pd.DataFrame(short_filenames)
    classes = pd.DataFrame(classes)
    xs = pd.DataFrame(xs)
    ys = pd.DataFrame(ys)
    heights = pd.DataFrame(heights)
    widths = pd.DataFrame(widths)
    
    shapes = pd.DataFrame(shapes)
    shapes = shapes.iloc[:, :-1]

    data = pd.concat([filenames, classes, xs, ys, widths, heights], axis = 1)
    data.columns = ['Filename', 'Class', 'x', 'y', 'width', 'height']
    shapes.columns = ['img_height', 'img_width']
    shapes['Filename'] = filenames
    
    return data, shapes, short_filenames

def preprocess(data, drop = True):
    data2 = data.copy()
    data2['Class_enc'] = LabelEncoder().fit_transform(data2['Class'])
    filenames = data2['Filename']
    if drop:
        data2.drop(['Class', 'Filename'], axis = 1, inplace = True)

    cols = data2.columns.tolist()
    cols = cols[-1:] + cols[:-1]
    data2 = data2[cols] 
    
    data2['x_max'] = data2['x'] + data2['width']
    data2['y_max'] = data2['y'] + data2['height']

    data2 = data2.iloc[:, [0, 1, -2, 2, -1]]
    
    return data2, filenames

data, shapes, short_names = to_df()
data2, filenames = preprocess(data)
# Out:
# 4371
# 4371
# 4371
# 4371
# 4371
# 4371

# %% [raw]
# data2.to_csv('/home/w/DS_Projects/Kaggle/Nature Conservancy/Scripts/BoundingBoxes_Liu Weijie/annots.txt',
#             header=None, index=None, sep=' ', mode='a')
#
# filenames.to_csv('/home/w/DS_Projects/Kaggle/Nature Conservancy/Scripts/BoundingBoxes_Liu Weijie/filenames.csv',
#             header=None, index=None, sep=' ', mode='a')
#
#
# fil = filenames.unique().tolist()
# with open(label_path + 'filenames.txt', "a+") as myfile:
#     for line in fil:
#         myfile.write(line + '\n')

# %%
def convert_darknet2(data2, shapes):
    
    class_enc = data2['Class_enc']
    data = data2.copy()
    data.drop(['Class_enc'], axis = 1, inplace = True)
    n_images = data.shape[0]
    x_s = []
    y_s = []
    w_s = []
    h_s = []
    
    for i in range(n_images):
    
        dw = 1./shapes.iloc[i, 1]
        dh = 1./shapes.iloc[i, 0]
        
        x = (data.iloc[i, 0] + data.iloc[i, 1])/2.0
        y = (data.iloc[i, 2] + data.iloc[i, 3])/2.0
        
        w = data.iloc[i, 1] - data.iloc[i, 0]
        h = data.iloc[i, 3] - data.iloc[i, 2]
        
        x = x*dw
        w = w*dw
        y = y*dh
        h = h*dh
        
        x_s.append(x)
        y_s.append(y)
        h_s.append(h)
        w_s.append(w)
    
    x_s = pd.DataFrame(x_s)
    y_s = pd.DataFrame(y_s)
    h_s = pd.DataFrame(h_s)
    w_s = pd.DataFrame(w_s)
    
    converted = pd.concat([x_s, y_s, w_s, h_s], axis = 1)
    converted.columns = ['x', 'y', 'width', 'height']
    converted['Class_enc'] = class_enc
    
    cols = converted.columns.tolist()
    cols = cols[-1:] + cols[:-1]
    converted = converted[cols] 
    
    return converted


def convert_faster(data2):
    
    class_enc = data2['Class_enc'] + 1
    data = data2.copy()
    data.drop(['Class_enc'], axis = 1, inplace = True)
    n_images = data.shape[0]
    x_s = []
    y_s = []
    x_s2 = []
    y_s2 = []
    
    for i in range(n_images):
        x = data.iloc[i, 0]
        y = data.iloc[i, 2]
        x2 = data.iloc[i, 1]
        y2 = data.iloc[i, 3]
        
        x_s.append(x)
        y_s.append(y)
        x_s2.append(x2)
        y_s2.append(y2)
        
    x_s = pd.DataFrame(x_s)
    y_s = pd.DataFrame(y_s)
    x_s2 = pd.DataFrame(x_s2)
    y_s2 = pd.DataFrame(y_s2)
    
    converted = pd.concat([x_s, y_s, x_s2, y_s2], axis = 1)
    converted.columns = ['x', 'y', 'x_end', 'y_end']
    converted['Class_enc'] = class_enc
    
    cols = converted.columns.tolist()
    cols = cols[-1:] + cols[:-1]
    converted = converted[cols] 
    
    return converted


def to_dict(data, filenames):

    datac = data.copy()
    datac['Filename'] = filenames
    mydict = {}
    for x in range(len(datac)):
        currentid = datac.loc[x, 'Filename']
        currentvalue = datac.iloc[x,:-1]
        mydict.setdefault(currentid, [])
        mydict[currentid].append(currentvalue)
        
    return mydict

# %%
conv = convert_darknet2(data2, shapes)
conv_dict = to_dict(conv, short_names)
new = iter_dict(conv_dict)

# %%
conv_dict
# Out:
# {'ALB/img_04102.jpg': [Class_enc           0
#   x            0.344531
#   y            0.647917
#   width        0.139063
#   height       0.126389
#   Name: 1350, dtype: object], 'ALB/img_01314.jpg': [Class_enc           0
#   x            0.519531
#   y            0.165278
#   width        0.301563
#   height       0.180556
#   Name: 442, dtype: object], 'ALB/img_05674.jpg': [Class_enc            0
#   x             0.263672
#   y             0.476667
#   width        0.0835938
#   height        0.225333
#   Name: 1784, dtype: object], 'YFT/img_07217.jpg': [Class_enc           6
#   x            0.687888
#   y            0.453113
#   width         0.42387
#   height       0.411742
#   Name: 4293, dtype: object], 'ALB/img_03706.jpg': [Class_enc           0
#   x            0.345313
#   y            0.642361
#   width        0.096875
#   height       0.179167
#   Name: 1236, dtype: object, Class_enc           0
#   x            0.107031
#   y            0.803472
#   width          0.0625
#   height       0.304167
#   Name: 1237, dtype: object], 'YFT/img_07752.jpg': [Class_enc           6
#   x            0.616966
#   y            0.381087
#   width        0.427194
#   height       0.493617
#   Name: 4356, dtype: object], 'YFT/img_05655.jpg': [Class_enc           6
#   x            0.254599
#   y            0.615642
#   width        0.191157
#   height       0.122143
#   Name: 4145, dtype: object], 'ALB/img_06126.jpg': [Class_enc           0
#   x            0.359375
#   y            0.208333
#   width        0.254688
#   height       0.161111
#   Name: 1909, dtype: object, Class_enc           0
#   x            0.283203
#   y            0.359722
#   width        0.241406
#   height       0.133333
#   Name: 1910, dtype: object, Class_enc           0
#   x            0.368359
#   y            0.525694
#   width        0.292969
#   height       0.234722
#   Name: 1911, dtype: object], 'ALB/img_00228.jpg': [Class_enc            0
#   x             0.670703
#   y             0.477778
#   width        0.0585938
#   height        0.122222
#   Name: 66, dtype: object], 'YFT/img_04413.jpg': [Class_enc           6
#   x             0.38924
#   y             0.63879
#   width        0.181184
#   height        0.18814
#   Name: 4033, dtype: object], 'ALB/img_02433.jpg': [Class_enc           0
#   x            0.479624
#   y             0.80571
#   width        0.142633
#   height       0.291086
#   Name: 820, dtype: object], 'YFT/img_01087.jpg': [Class_enc           6
#   x            0.523704
#   y            0.425988
#   width        0.183007
#   height       0.184834
#   Name: 3684, dtype: object], 'ALB/img_02388.jpg': [Class_enc            0
#   x             0.414844
#   y             0.696528
#   width         0.114063
#   height       0.0680556
#   Name: 801, dtype: object], 'ALB/img_07768.jpg': [Class_enc           0
#   x            0.485992
#   y            0.470225
#   width        0.069187
#   height       0.253223
#   Name: 2454, dtype: object], 'YFT/img_06486.jpg': [Class_enc           6
#   x            0.390625
#   y            0.646178
#   width        0.172872
#   height       0.179275
#   Name: 4226, dtype: object], 'ALB/img_00508.jpg': [Class_enc           0
#   x            0.574219
#   y            0.626389
#   width           0.075
#   height       0.241667
#   Name: 167, dtype: object], 'BET/img_02343.jpg': [Class_enc           1
#   x            0.346654
#   y            0.325526
#   width        0.312071
#   height        0.20484
#   Name: 2616, dtype: object], 'YFT/img_02150.jpg': [Class_enc           6
#   x            0.652988
#   y            0.533612
#   width        0.133217
#   height       0.305204
#   Name: 3797, dtype: object], 'ALB/img_01529.jpg': [Class_enc            0
#   x             0.850252
#   y             0.570896
#   width        0.0578859
#   height         0.11791
#   Name: 523, dtype: object], 'YFT/img_04698.jpg': [Class_enc           6
#   x            0.759918
#   y            0.380221
#   width        0.336325
#   height       0.394011
#   Name: 4060, dtype: object], 'ALB/img_03821.jpg': [Class_enc           0
#   x            0.485156
#   y            0.702083
#   width        0.120313
#   height       0.226389
#   Name: 1274, dtype: object], 'YFT/img_03400.jpg': [Class_enc            6
#   x             0.355441
#   y             0.603822
#   width        0.0725842
#   height        0.275808
#   Name: 3933, dtype: object], 'ALB/img_06383.jpg': [Class_enc           0
#   x            0.790625
#   y             0.34375
#   width        0.234375
#   height       0.248611
#   Name: 1976, dtype: object], 'ALB/img_02184.jpg': [Class_enc           0
#   x            0.557031
#   y            0.303472
#   width        0.271875
#   height       0.204167
#   Name: 746, dtype: object], 'YFT/img_02368.jpg': [Class_enc           6
#   x            0.566268
#   y            0.524269
#   width        0.209441
#   height       0.157281
#   Name: 3824, dtype: object], 'YFT/img_07166.jpg': [Class_enc            6
#   x             0.420196
#   y             0.373378
#   width        0.0622513
#   height        0.250894
#   Name: 4291, dtype: object], 'ALB/img_04093.jpg': [Class_enc           0
#   x            0.267578
#   y            0.592361
#   width        0.113281
#   height       0.109722
#   Name: 1347, dtype: object], 'ALB/img_02025.jpg': [Class_enc            0
#   x             0.308984
#   y             0.623611
#   width         0.125781
#   height       0.0777778
#   Name: 702, dtype: object], 'YFT/img_01727.jpg': [Class_enc           6
#   x            0.189956
#   y            0.693851
#   width        0.187971
#   height       0.116913
#   Name: 3754, dtype: object], 'YFT/img_02858.jpg': [Class_enc           6
#   x            0.388132
#   y            0.647163
#   width        0.175643
#   height       0.177305
#   Name: 3872, dtype: object], 'SHARK/img_05464.jpg': [Class_enc           5
#   x            0.498828
#   y            0.708932
#   width        0.416406
#   height       0.228953
#   Name: 3508, dtype: object], 'ALB/img_01079.jpg': [Class_enc           0
#   x            0.330469
#   y            0.240972
#   width        0.265625
#   height       0.145833
#   Name: 343, dtype: object, Class_enc           0
#   x            0.501172
#   y            0.481944
#   width        0.241406
#   height       0.386111
#   Name: 344, dtype: object, Class_enc           0
#   x            0.638281
#   y            0.220833
#   width        0.171875
#   height       0.166667
#   Name: 345, dtype: object, Class_enc           0
#   x            0.469922
#   y            0.620139
#   width        0.283594
#   height       0.356944
#   Name: 346, dtype: object, Class_enc           0
#   x            0.422266
#   y               0.725
#   width        0.308594
#   height       0.191667
#   Name: 347, dtype: object, Class_enc            0
#   x            0.0839844
#   y             0.575694
#   width         0.132031
#   height        0.140278
#   Name: 348, dtype: object, Class_enc            0
#   x            0.0578125
#   y             0.321528
#   width        0.0734375
#   height        0.251389
#   Name: 349, dtype: object], 'ALB/img_01445.jpg': [Class_enc           0
#   x            0.605469
#   y            0.180556
#   width        0.245313
#   height       0.166667
#   Name: 498, dtype: object], 'BET/img_04718.jpg': [Class_enc           1
#   x             0.30264
#   y            0.546674
#   width        0.150575
#   height       0.475785
#   Name: 2700, dtype: object], 'SHARK/img_02087.jpg': [Class_enc            5
#   x             0.156641
#   y             0.698611
#   width        0.0382813
#   height        0.183333
#   Name: 3424, dtype: object, Class_enc            5
#   x             0.123438
#   y             0.734722
#   width        0.0453125
#   height        0.169444
#   Name: 3425, dtype: object], 'BET/img_06777.jpg': [Class_enc           1
#   x            0.592208
#   y            0.190618
#   width        0.401424
#   height       0.323628
#   Name: 2767, dtype: object], 'LAG/img_03774.jpg': [Class_enc           3
#   x            0.635814
#   y            0.518711
#   width        0.104528
#   height        0.14461
#   Name: 2984, dtype: object], 'ALB/img_00038.jpg': [Class_enc            0
#   x             0.615625
#   y             0.454861
#   width        0.0671875
#   height        0.204167
#   Name: 18, dtype: object], 'DOL/img_05934.jpg': [Class_enc           2
#   x            0.591711
#   y            0.490077
#   width        0.105237
#   height       0.297694
#   Name: 2916, dtype: object], 'ALB/img_06823.jpg': [Class_enc           0
#   x            0.682031
#   y            0.265972
#   width        0.284375
#   height       0.315278
#   Name: 2108, dtype: object, Class_enc           0
#   x            0.337109
#   y            0.472917
#   width        0.135156
#   height       0.151389
#   Name: 2109, dtype: object], 'ALB/img_06479.jpg': [Class_enc           0
#   x            0.460547
#   y            0.226389
#   width        0.292969
#   height       0.183333
#   Name: 2014, dtype: object, Class_enc           0
#   x            0.801563
#   y            0.447917
#   width        0.104688
#   height       0.465278
#   Name: 2015, dtype: object], 'ALB/img_01196.jpg': [Class_enc           0
#   x            0.817188
#   y            0.464583
#   width        0.240625
#   height       0.181944
#   Name: 396, dtype: object, Class_enc           0
#   x            0.653516
#   y            0.326389
#   width        0.241406
#   height       0.161111
#   Name: 397, dtype: object, Class_enc           0
#   x            0.583984
#   y              0.1875
#   width        0.277344
#   height       0.163889
#   Name: 398, dtype: object, Class_enc            0
#   x            0.0878906
#   y             0.457639
#   width         0.113281
#   height        0.156944
#   Name: 399, dtype: object], 'YFT/img_06487.jpg': [Class_enc           6
#   x            0.272883
#   y            0.617021
#   width        0.346299
#   height       0.273286
#   Name: 4227, dtype: object], 'ALB/img_02019.jpg': [Class_enc           0
#   x            0.392969
#   y            0.280667
#   width        0.221875
#   height          0.316
#   Name: 701, dtype: object], 'BET/img_02757.jpg': [Class_enc           1
#   x            0.259949
#   y            0.459911
#   width        0.162489
#   height       0.471871
#   Name: 2638, dtype: object], 'YFT/img_02255.jpg': [Class_enc           6
#   x            0.628879
#   y            0.831678
#   width        0.610594
#   height       0.330024
#   Name: 3809, dtype: object], 'YFT/img_05048.jpg': [Class_enc           6
#   x            0.460439
#   y            0.577424
#   width        0.176197
#   height       0.324756
#   Name: 4092, dtype: object], 'OTHER/img_02160.jpg': [Class_enc            4
#   x             0.621668
#   y             0.535128
#   width        0.0581585
#   height        0.135529
#   Name: 3126, dtype: object], 'ALB/img_07168.jpg': [Class_enc           0
#   x            0.594182
#   y            0.250057
#   width        0.277861
#   height       0.186427
#   Name: 2228, dtype: object], 'ALB/img_06194.jpg': [Class_enc            0
#   x             0.257422
#   y             0.620833
#   width         0.132031
#   height       0.0916667
#   Name: 1932, dtype: object], 'ALB/img_02777.jpg': [Class_enc            0
#   x             0.208054
#   y             0.265672
#   width        0.0889262
#   height        0.310448
#   Name: 912, dtype: object], 'YFT/img_06971.jpg': [Class_enc           6
#   x             0.57818
#   y            0.582886
#   width        0.275377
#   height       0.230824
#   Name: 4271, dtype: object], 'YFT/img_05166.jpg': [Class_enc           6
#   x             0.24047
#   y            0.576241
#   width        0.154034
#   height       0.151694
#   Name: 4104, dtype: object], 'ALB/img_06991.jpg': [Class_enc            0
#   x             0.487461
#   y             0.442897
#   width        0.0736677
#   height         0.24234
#   Name: 2158, dtype: object], 'YFT/img_07649.jpg': [Class_enc            6
#   x             0.365137
#   y             0.512214
#   width         0.111924
#   height       0.0847124
#   Name: 4345, dtype: object], 'ALB/img_01936.jpg': [Class_enc           0
#   x             0.61875
#   y            0.676389
#   width        0.084375
#   height       0.238889
#   Name: 675, dtype: object, Class_enc           0
#   x            0.476562
#   y            0.797222
#   width        0.115625
#   height       0.244444
#   Name: 676, dtype: object, Class_enc           0
#   x              0.4875
#   y            0.868056
#   width        0.167188
#   height       0.236111
#   Name: 677, dtype: object, Class_enc            0
#   x             0.670703
#   y             0.929167
#   width        0.0585938
#   height        0.113889
#   Name: 678, dtype: object], 'YFT/img_06048.jpg': [Class_enc           6
#   x              0.3499
#   y            0.643223
#   width        0.154588
#   height       0.169425
#   Name: 4176, dtype: object], 'ALB/img_04243.jpg': [Class_enc           0
#   x            0.391016
#   y            0.605556
#   width        0.114844
#   height       0.202778
#   Name: 1369, dtype: object], 'BET/img_05110.jpg': [Class_enc           1
#   x            0.599819
#   y             0.24298
#   width        0.280964
#   height       0.243568
#   Name: 2716, dtype: object, Class_enc           1
#   x            0.352114
#   y            0.355644
#   width        0.259453
#   height       0.259453
#   Name: 2717, dtype: object], 'ALB/img_00384.jpg': [Class_enc           0
#   x            0.633984
#   y            0.676389
#   width        0.124219
#   height       0.183333
#   Name: 128, dtype: object], 'ALB/img_05690.jpg': [Class_enc           0
#   x            0.666406
#   y            0.402778
#   width          0.0375
#   height       0.144444
#   Name: 1792, dtype: object], 'YFT/img_06027.jpg': [Class_enc           6
#   x            0.338542
#   y            0.546572
#   width        0.280363
#   height       0.349882
#   Name: 4175, dtype: object], 'ALB/img_05107.jpg': [Class_enc            0
#   x             0.798658
#   y             0.329851
#   width        0.0553691
#   height       0.0776119
#   Name: 1618, dtype: object], 'YFT/img_05370.jpg': [Class_enc           6
#   x             0.48371
#   y            0.606915
#   width        0.234929
#   height       0.233737
#   Name: 4123, dtype: object], 'ALB/img_02807.jpg': [Class_enc            0
#   x             0.750419
#   y             0.377612
#   width        0.0780201
#   height        0.140299
#   Name: 921, dtype: object], 'ALB/img_05193.jpg': [Class_enc           0
#   x            0.439063
#   y            0.282639
#   width        0.248438
#   height         0.2125
#   Name: 1643, dtype: object, Class_enc           0
#   x            0.170313
#   y              0.2125
#   width           0.125
#   height            0.2
#   Name: 1644, dtype: object], 'YFT/img_04292.jpg': [Class_enc           6
#   x            0.635527
#   y             0.55063
#   width        0.149601
#   height       0.228526
#   Name: 4015, dtype: object], 'ALB/img_00742.jpg': [Class_enc            0
#   x             0.503516
#   y              0.17803
#   width        0.0929688
#   height        0.167749
#   Name: 230, dtype: object], 'ALB/img_04220.jpg': [Class_enc            0
#   x             0.534483
#   y             0.401811
#   width        0.0893417
#   height        0.229805
#   Name: 1366, dtype: object], 'BET/img_03287.jpg': [Class_enc            1
#   x             0.571193
#   y             0.566854
#   width        0.0390503
#   height          0.1512
#   Name: 2649, dtype: object, Class_enc           1
#   x            0.528668
#   y            0.764533
#   width        0.130719
#   height       0.244156
#   Name: 2650, dtype: object], 'ALB/img_04954.jpg': [Class_enc           0
#   x            0.333984
#   y            0.165972
#   width        0.249219
#   height       0.179167
#   Name: 1562, dtype: object], 'ALB/img_02052.jpg': [Class_enc            0
#   x             0.322656
#   y             0.614583
#   width         0.123438
#   height       0.0930556
#   Name: 714, dtype: object], 'ALB/img_03990.jpg': [Class_enc            0
#   x             0.817114
#   y             0.434328
#   width        0.0302013
#   height        0.167164
#   Name: 1306, dtype: object, Class_enc            0
#   x             0.534815
#   y             0.126119
#   width        0.0192953
#   height       0.0880597
#   Name: 1307, dtype: object, Class_enc            0
#   x             0.506292
#   y             0.101493
#   width        0.0377517
#   height       0.0746269
#   Name: 1308, dtype: object], 'BET/img_00583.jpg': [Class_enc           1
#   x            0.235791
#   y            0.458824
#   width        0.126748
#   height       0.457519
#   Name: 2539, dtype: object], 'ALB/img_07709.jpg': [Class_enc            0
#   x             0.389778
#   y             0.383035
#   width         0.234501
#   height       0.0903505
#   Name: 2427, dtype: object], 'YFT/img_01346.jpg': [Class_enc           6
#   x            0.314388
#   y            0.413811
#   width        0.091338
#   height       0.175266
#   Name: 3707, dtype: object], 'ALB/img_07404.jpg': [Class_enc           0
#   x            0.556349
#   y            0.178054
#   width        0.248034
#   height       0.144006
#   Name: 2315, dtype: object, Class_enc           0
#   x            0.722909
#   y            0.373969
#   width        0.230766
#   height       0.272384
#   Name: 2316, dtype: object], 'YFT/img_00298.jpg': [Class_enc           6
#   x            0.564409
#   y            0.627131
#   width        0.298172
#   height        0.27051
#   Name: 3607, dtype: object], 'SHARK/img_06467.jpg': [Class_enc            5
#   x             0.457422
#   y             0.597917
#   width        0.0414063
#   height        0.184722
#   Name: 3535, dtype: object], 'ALB/img_02821.jpg': [Class_enc           0
#   x            0.398438
#   y            0.610417
#   width         0.04375
#   height       0.218056
#   Name: 924, dtype: object], 'ALB/img_03686.jpg': [Class_enc           0
#   x            0.530469
#   y            0.245333
#   width        0.353125
#   height       0.210667
#   Name: 1222, dtype: object, Class_enc           0
#   x            0.596875
#   y            0.339333
#   width         0.28125
#   height          0.276
#   Name: 1223, dtype: object, Class_enc           0
#   x            0.664453
#   y               0.492
#   width        0.350781
#   height       0.189333
#   Name: 1224, dtype: object, Class_enc           0
#   x            0.809375
#   y            0.630667
#   width        0.209375
#   height           0.32
#   Name: 1225, dtype: object], 'ALB/img_06693.jpg': [Class_enc           0
#   x            0.739453
#   y            0.158667
#   width        0.213281
#   height          0.304
#   Name: 2079, dtype: object], 'ALB/img_00525.jpg': [Class_enc           0
#   x            0.307422
#   y            0.385333
#   width        0.157031
#   height       0.194667
#   Name: 170, dtype: object], 'ALB/img_00447.jpg': [Class_enc           0
#   x            0.524609
#   y            0.242361
#   width        0.211719
#   height       0.251389
#   Name: 138, dtype: object, Class_enc           0
#   x            0.646094
#   y             0.20625
#   width        0.257812
#   height       0.209722
#   Name: 139, dtype: object, Class_enc           0
#   x            0.730469
#   y            0.404861
#   width        0.246875
#   height         0.2875
#   Name: 140, dtype: object, Class_enc           0
#   x            0.598047
#   y            0.477083
#   width        0.241406
#   height       0.326389
#   Name: 141, dtype: object, Class_enc           0
#   x            0.510156
#   y            0.393056
#   width          0.2875
#   height       0.152778
#   Name: 142, dtype: object, Class_enc           0
#   x            0.514844
#   y            0.565278
#   width        0.242188
#   height       0.233333
#   Name: 143, dtype: object, Class_enc           0
#   x            0.259766
#   y              0.3625
#   width        0.235156
#   height       0.127778
#   Name: 144, dtype: object, Class_enc           0
#   x            0.133984
#   y            0.245139
#   width        0.135156
#   height       0.143056
#   Name: 145, dtype: object], 'ALB/img_01992.jpg': [Class_enc           0
#   x            0.366406
#   y               0.308
#   width        0.173438
#   height          0.288
#   Name: 694, dtype: object], 'ALB/img_00897.jpg': [Class_enc           0
#   x            0.483221
#   y            0.278358
#   width        0.033557
#   height       0.156716
#   Name: 275, dtype: object, Class_enc            0
#   x             0.510487
#   y             0.262687
#   width        0.0276846
#   height        0.158209
#   Name: 276, dtype: object, Class_enc            0
#   x             0.533138
#   y             0.286567
#   width        0.0360738
#   height        0.185075
#   Name: 277, dtype: object], 'LAG/img_01952.jpg': [Class_enc           3
#   x            0.597697
#   y            0.587524
#   width        0.115531
#   height       0.202594
#   Name: 2963, dtype: object, Class_enc           3
#   x            0.768439
#   y            0.480987
#   width        0.104921
#   height       0.158582
#   Name: 2964, dtype: object], 'YFT/img_03541.jpg': [Class_enc           6
#   x            0.359597
#   y            0.475847
#   width         0.15625
#   height       0.197329
#   Name: 3945, dtype: object], 'ALB/img_00121.jpg': [Class_enc           0
#   x            0.400781
#   y            0.611806
#   width         0.08125
#   height       0.201389
#   Name: 36, dtype: object], 'YFT/img_01691.jpg': [Class_enc           6
#   x            0.383388
#   y            0.617451
#   width        0.199554
#   height       0.177087
#   Name: 3746, dtype: object, Class_enc            6
#   x             0.121122
#   y             0.794832
#   width        0.0390503
#   height        0.260041
#   Name: 3747, dtype: object], 'YFT/img_07633.jpg': [Class_enc           6
#   x               0.479
#   y            0.584342
#   width         0.25543
#   height       0.338591
#   Name: 4342, dtype: object], 'SHARK/img_04131.jpg': [Class_enc            5
#   x             0.452734
#   y             0.591667
#   width        0.0335937
#   height        0.155556
#   Name: 3476, dtype: object], 'ALB/img_02192.jpg': [Class_enc           0
#   x             0.47453
#   y            0.494429
#   width        0.096395
#   height       0.103064
#   Name: 751, dtype: object], 'SHARK/img_06677.jpg': [Class_enc            5
#   x             0.451172
#   y             0.595139
#   width        0.0632812
#   height        0.173611
#   Name: 3545, dtype: object], 'OTHER/img_05756.jpg': [Class_enc            4
#   x             0.634242
#   y             0.551546
#   width        0.0872378
#   height        0.383532
#   Name: 3291, dtype: object], 'ALB/img_04098.jpg': [Class_enc           0
#   x            0.247064
#   y            0.198507
#   width        0.130034
#   height       0.256716
#   Name: 1348, dtype: object], 'DOL/img_04385.jpg': [Class_enc           2
#   x            0.342074
#   y            0.538873
#   width        0.337555
#   height       0.166994
#   Name: 2890, dtype: object], 'ALB/img_05566.jpg': [Class_enc            0
#   x             0.244141
#   y             0.420667
#   width        0.0617188
#   height           0.228
#   Name: 1761, dtype: object], 'OTHER/img_02874.jpg': [Class_enc            4
#   x             0.392374
#   y             0.702793
#   width            0.134
#   height       0.0405189
#   Name: 3156, dtype: object], 'ALB/img_06022.jpg': [Class_enc            0
#   x             0.386719
#   y             0.571528
#   width        0.0859375
#   height        0.190278
#   Name: 1872, dtype: object], 'YFT/img_00440.jpg': [Class_enc           6
#   x            0.263259
#   y            0.620392
#   width        0.108878
#   height       0.122961
#   Name: 3623, dtype: object], 'ALB/img_07740.jpg': [Class_enc            0
#   x              0.67871
#   y             0.461959
#   width        0.0823921
#   height        0.163044
#   Name: 2441, dtype: object, Class_enc            0
#   x             0.540023
#   y             0.531883
#   width        0.0577863
#   height        0.133219
#   Name: 2442, dtype: object, Class_enc           0
#   x            0.487083
#   y            0.682003
#   width        0.090594
#   height       0.220044
#   Name: 2443, dtype: object], 'ALB/img_07890.jpg': [Class_enc            0
#   x             0.690453
#   y             0.497087
#   width        0.0738174
#   height        0.147138
#   Name: 2502, dtype: object, Class_enc            0
#   x             0.543191
#   y               0.7337
#   width        0.0708348
#   height        0.257159
#   Name: 2503, dtype: object], 'YFT/img_02219.jpg': [Class_enc           6
#   x            0.651319
#   y             0.64223
#   width        0.145723
#   height        0.21262
#   Name: 3804, dtype: object], 'YFT/img_04594.jpg': [Class_enc           6
#   x            0.226895
#   y            0.582644
#   width        0.133533
#   height       0.129039
#   Name: 4049, dtype: object], 'ALB/img_05442.jpg': [Class_enc           0
#   x            0.811719
#   y            0.821333
#   width        0.307813
#   height       0.325333
#   Name: 1725, dtype: object], 'ALB/img_07766.jpg': [Class_enc           0
#   x            0.586624
#   y            0.225346
#   width        0.274019
#   height       0.167021
#   Name: 2450, dtype: object, Class_enc           0
#   x            0.212132
#   y            0.191544
#   width        0.196846
#   height       0.167021
#   Name: 2451, dtype: object], 'OTHER/img_03841.jpg': [Class_enc            4
#   x             0.633064
#   y             0.552943
#   width        0.0793786
#   height        0.372354
#   Name: 3191, dtype: object], 'OTHER/img_04652.jpg': [Class_enc           4
#   x            0.757043
#   y            0.639919
#   width        0.411432
#   height       0.338123
#   Name: 3226, dtype: object], 'YFT/img_01235.jpg': [Class_enc           6
#   x            0.615373
#   y            0.572768
#   width        0.200877
#   height       0.154826
#   Name: 3695, dtype: object], 'YFT/img_00477.jpg': [Class_enc           6
#   x            0.405395
#   y            0.675695
#   width         0.12046
#   height       0.102957
#   Name: 3625, dtype: object], 'SHARK/img_03131.jpg': [Class_enc            5
#   x             0.440625
#   y             0.591667
#   width        0.0734375
#   height        0.180556
#   Name: 3454, dtype: object], 'ALB/img_02488.jpg': [Class_enc           0
#   x            0.249161
#   y            0.208209
#   width        0.124161
#   height       0.228358
#   Name: 836, dtype: object], 'ALB/img_01304.jpg': [Class_enc           0
#   x            0.292187
#   y            0.619444
#   width             0.1
#   height       0.127778
#   Name: 439, dtype: object], 'YFT/img_05400.jpg': [Class_enc            6
#   x             0.720907
#   y            0.0754813
#   width        0.0769652
#   height         0.14691
#   Name: 4126, dtype: object], 'YFT/img_03756.jpg': [Class_enc           6
#   x            0.215536
#   y            0.512057
#   width        0.196144
#   height       0.231678
#   Name: 3968, dtype: object], 'ALB/img_05511.jpg': [Class_enc            0
#   x             0.620298
#   y             0.453343
#   width        0.0681818
#   height       0.0821727
#   Name: 1745, dtype: object], 'YFT/img_06854.jpg': [Class_enc           6
#   x            0.234098
#   y            0.579689
#   width        0.152371
#   height       0.144799
#   Name: 4263, dtype: object], 'ALB/img_04290.jpg': [Class_enc            0
#   x             0.540625
#   y             0.571528
#   width        0.0796875
#   height        0.184722
#   Name: 1373, dtype: object], 'BET/img_02168.jpg': [Class_enc           1
#   x            0.464963
#   y            0.687167
#   width         0.10259
#   height       0.287104
#   Name: 2611, dtype: object], 'ALB/img_07255.jpg': [Class_enc           0
#   x            0.705327
#   y            0.438716
#   width        0.252743
#   height       0.283547
#   Name: 2265, dtype: object, Class_enc           0
#   x            0.840175
#   y             0.39825
#   width        0.197799
#   height       0.218242
#   Name: 2266, dtype: object, Class_enc           0
#   x            0.734525
#   y            0.226614
#   width        0.258395
#   height       0.189776
#   Name: 2267, dtype: object, Class_enc           0
#   x            0.782562
#   y            0.658075
#   width         0.22637
#   height       0.147355
#   Name: 2268, dtype: object, Class_enc           0
#   x            0.409413
#   y            0.165495
#   width        0.210358
#   height       0.156844
#   Name: 2269, dtype: object], 'YFT/img_01749.jpg': [Class_enc           6
#   x            0.599819
#   y            0.353844
#   width        0.487467
#   height       0.436587
#   Name: 3758, dtype: object], 'OTHER/img_00862.jpg': [Class_enc           4
#   x            0.708905
#   y            0.358382
#   width        0.315942
#   height       0.194211
#   Name: 3083, dtype: object], 'YFT/img_03367.jpg': [Class_enc           6
#   x            0.348515
#   y            0.640268
#   width        0.147385
#   height       0.155634
#   Name: 3929, dtype: object], 'OTHER/img_01483.jpg': [Class_enc           4
#   x             0.71146
#   y            0.372005
#   width        0.313978
#   height       0.186526
#   Name: 3100, dtype: object], 'SHARK/img_06956.jpg': [Class_enc           5
#   x            0.430078
#   y            0.660417
#   width        0.113281
#   height       0.101389
#   Name: 3554, dtype: object], 'OTHER/img_02051.jpg': [Class_enc            4
#   x             0.642888
#   y             0.531635
#   width        0.0675897
#   height        0.343712
#   Name: 3123, dtype: object], 'ALB/img_00719.jpg': [Class_enc           0
#   x            0.479688
#   y            0.624743
#   width        0.121875
#   height       0.196099
#   Name: 224, dtype: object], 'BET/img_01343.jpg': [Class_enc           1
#   x            0.249194
#   y            0.416855
#   width        0.142964
#   height       0.452735
#   Name: 2568, dtype: object], 'YFT/img_04360.jpg': [Class_enc           6
#   x            0.400321
#   y            0.639775
#   width        0.176751
#   height        0.18026
#   Name: 4022, dtype: object, Class_enc            6
#   x             0.119958
#   y             0.832348
#   width        0.0548537
#   height        0.202916
#   Name: 4023, dtype: object], 'ALB/img_05707.jpg': [Class_enc            0
#   x             0.321875
#   y              0.63125
#   width         0.145313
#   height       0.0986111
#   Name: 1795, dtype: object], 'ALB/img_02494.jpg': [Class_enc           0
#   x            0.741016
#   y            0.363889
#   width        0.247656
#   height          0.175
#   Name: 841, dtype: object], 'YFT/img_01007.jpg': [Class_enc           6
#   x            0.399107
#   y            0.103607
#   width        0.111856
#   height       0.153118
#   Name: 3679, dtype: object, Class_enc           6
#   x            0.844545
#   y            0.104065
#   width        0.118475
#   height       0.100856
#   Name: 3680, dtype: object], 'ALB/img_05810.jpg': [Class_enc            0
#   x             0.505078
#   y               0.6375
#   width        0.0710937
#   height        0.244444
#   Name: 1822, dtype: object, Class_enc           0
#   x            0.553906
#   y            0.656944
#   width        0.053125
#   height       0.227778
#   Name: 1823, dtype: object], 'ALB/img_05206.jpg': [Class_enc            0
#   x              0.30625
#   y             0.614583
#   width         0.146875
#   height       0.0958333
#   Name: 1648, dtype: object], 'OTHER/img_07839.jpg': [Class_enc           4
#   x            0.645835
#   y            0.702331
#   width        0.064053
#   height       0.169386
#   Name: 3374, dtype: object], 'YFT/img_00214.jpg': [Class_enc           6
#   x            0.742452
#   y            0.326228
#   width        0.283611
#   height       0.260629
#   Name: 3590, dtype: object, Class_enc           6
#   x             0.28874
#   y            0.173851
#   width        0.287582
#   height       0.265336
#   Name: 3591, dtype: object], 'YFT/img_01008.jpg': [Class_enc           6
#   x            0.411186
#   y             0.67393
#   width        0.133367
#   height       0.101781
#   Name: 3681, dtype: object], 'YFT/img_06417.jpg': [Class_enc           6
#   x            0.160406
#   y            0.577305
#   width        0.227726
#   height       0.326241
#   Name: 4217, dtype: object], 'ALB/img_04708.jpg': [Class_enc           0
#   x            0.575391
#   y            0.773611
#   width        0.105469
#   height       0.277778
#   Name: 1486, dtype: object, Class_enc           0
#   x            0.640625
#   y            0.514583
#   width           0.075
#   height       0.168056
#   Name: 1487, dtype: object], 'ALB/img_00337.jpg': [Class_enc           0
#   x            0.646094
#   y            0.234028
#   width        0.273438
#   height       0.254167
#   Name: 104, dtype: object, Class_enc           0
#   x            0.576953
#   y            0.350694
#   width        0.278906
#   height       0.159722
#   Name: 105, dtype: object, Class_enc           0
#   x            0.430469
#   y             0.25625
#   width        0.217188
#   height       0.279167
#   Name: 106, dtype: object, Class_enc           0
#   x            0.110156
#   y            0.395833
#   width         0.14375
#   height       0.252778
#   Name: 107, dtype: object, Class_enc           0
#   x            0.175391
#   y            0.590278
#   width        0.152344
#   height       0.216667
#   Name: 108, dtype: object], 'SHARK/img_06163.jpg': [Class_enc           5
#   x            0.352734
#   y            0.348667
#   width        0.333594
#   height       0.265333
#   Name: 3528, dtype: object], 'DOL/img_06284.jpg': [Class_enc           2
#   x            0.308597
#   y            0.543051
#   width        0.284935
#   height        0.17791
#   Name: 2923, dtype: object], 'ALB/img_03860.jpg': [Class_enc            0
#   x             0.438339
#   y             0.853731
#   width        0.0545302
#   height        0.250746
#   Name: 1285, dtype: object], 'SHARK/img_06303.jpg': [Class_enc           5
#   x            0.466406
#   y            0.706366
#   width        0.354688
#   height         0.2423
#   Name: 3530, dtype: object], 'LAG/img_06876.jpg': [Class_enc           3
#   x             0.60536
#   y            0.582284
#   width        0.136358
#   height       0.200499
#   Name: 3027, dtype: object, Class_enc            3
#   x             0.772762
#   y             0.491117
#   width        0.0860589
#   height        0.159281
#   Name: 3028, dtype: object], 'ALB/img_03599.jpg': [Class_enc            0
#   x             0.285156
#   y             0.613194
#   width         0.126562
#   height       0.0847222
#   Name: 1185, dtype: object], 'SHARK/img_07661.jpg': [Class_enc           5
#   x            0.195312
#   y            0.666324
#   width           0.375
#   height       0.314168
#   Name: 3568, dtype: object], 'YFT/img_04933.jpg': [Class_enc           6
#   x            0.586492
#   y            0.620749
#   width        0.301973
#   height       0.267232
#   Name: 4080, dtype: object], 'BET/img_04619.jpg': [Class_enc           1
#   x            0.302143
#   y            0.324221
#   width        0.289237
#   height        0.20571
#   Name: 2696, dtype: object], 'ALB/img_02489.jpg': [Class_enc           0
#   x            0.892188
#   y            0.403472
#   width        0.140625
#   height       0.165278
#   Name: 837, dtype: object], 'ALB/img_02875.jpg': [Class_enc            0
#   x             0.475252
#   y             0.328358
#   width        0.0746644
#   height         0.19403
#   Name: 936, dtype: object, Class_enc            0
#   x             0.515101
#   y              0.48209
#   width        0.0419463
#   height        0.140299
#   Name: 937, dtype: object], 'YFT/img_02179.jpg': [Class_enc           6
#   x            0.395471
#   y             0.63865
#   width        0.176694
#   height       0.162511
#   Name: 3800, dtype: object], 'ALB/img_02549.jpg': [Class_enc           0
#   x            0.366406
#   y            0.538889
#   width           0.125
#   height       0.147222
#   Name: 858, dtype: object], 'ALB/img_01338.jpg': [Class_enc           0
#   x            0.355859
#   y            0.417361
#   width        0.247656
#   height         0.1875
#   Name: 456, dtype: object, Class_enc           0
#   x            0.739844
#   y            0.609722
#   width        0.245313
#   height       0.169444
#   Name: 457, dtype: object], 'LAG/img_01037.jpg': [Class_enc           3
#   x            0.620292
#   y            0.518362
#   width        0.140288
#   height       0.142515
#   Name: 2953, dtype: object], 'ALB/img_03458.jpg': [Class_enc           0
#   x            0.785938
#   y              0.4625
#   width        0.254688
#   height       0.180556
#   Name: 1137, dtype: object], 'OTHER/img_01327.jpg': [Class_enc            4
#   x             0.642495
#   y             0.545258
#   width        0.0864519
#   height        0.375149
#   Name: 3090, dtype: object], 'ALB/img_01396.jpg': [Class_enc           0
#   x            0.544531
#   y            0.540972
#   width        0.107813
#   height       0.151389
#   Name: 482, dtype: object], 'OTHER/img_06766.jpg': [Class_enc            4
#   x             0.636993
#   y             0.549799
#   width        0.0730911
#   height        0.366067
#   Name: 3333, dtype: object], 'ALB/img_06566.jpg': [Class_enc           0
#   x            0.661719
#   y            0.411111
#   width        0.295313
#   height       0.261111
#   Name: 2035, dtype: object], 'ALB/img_04362.jpg': [Class_enc            0
#   x             0.540234
#   y              0.58125
#   width        0.0976562
#   height        0.184722
#   Name: 1406, dtype: object], 'ALB/img_02948.jpg': [Class_enc            0
#   x             0.488245
#   y             0.472841
#   width        0.0642633
#   height         0.25766
#   Name: 967, dtype: object, Class_enc            0
#   x             0.391458
#   y             0.314067
#   width        0.0352665
#   height       0.0988858
#   Name: 968, dtype: object], 'OTHER/img_00698.jpg': [Class_enc           4
#   x            0.408289
#   y            0.557134
#   width        0.162687
#   height        0.16976
#   Name: 3075, dtype: object], 'ALB/img_00744.jpg': [Class_enc            0
#   x             0.508984
#   y             0.600694
#   width        0.0929688
#   height        0.248611
#   Name: 231, dtype: object, Class_enc            0
#   x             0.573047
#   y             0.572222
#   width        0.0757813
#   height        0.269444
#   Name: 232, dtype: object], 'YFT/img_03046.jpg': [Class_enc           6
#   x            0.906749
#   y            0.806428
#   width        0.175643
#   height       0.184222
#   Name: 3893, dtype: object], 'YFT/img_03388.jpg': [Class_enc           6
#   x            0.195313
#   y            0.563593
#   width        0.208887
#   height       0.209929
#   Name: 3931, dtype: object], 'YFT/img_07466.jpg': [Class_enc           6
#   x            0.386746
#   y            0.619582
#   width        0.205009
#   height       0.187155
#   Name: 4321, dtype: object], 'SHARK/img_01986.jpg': [Class_enc           5
#   x            0.372266
#   y               0.394
#   width        0.372656
#   height          0.188
#   Name: 3421, dtype: object], 'ALB/img_05494.jpg': [Class_enc           0
#   x            0.703516
#   y            0.569444
#   width        0.250781
#   height       0.183333
#   Name: 1737, dtype: object], 'ALB/img_07801.jpg': [Class_enc           0
#   x            0.605265
#   y            0.537516
#   width        0.318011
#   height       0.225346
#   Name: 2464, dtype: object, Class_enc           0
#   x            0.318943
#   y            0.200492
#   width        0.253141
#   height       0.153103
#   Name: 2465, dtype: object], 'ALB/img_00898.jpg': [Class_enc            0
#   x             0.608984
#   y             0.728472
#   width        0.0929688
#   height        0.254167
#   Name: 278, dtype: object], 'ALB/img_00085.jpg': [Class_enc           0
#   x            0.559375
#   y            0.293056
#   width         0.29375
#   height       0.183333
#   Name: 27, dtype: object], 'ALB/img_03277.jpg': [Class_enc            0
#   x             0.479446
#   y             0.278358
#   width        0.0478188
#   height        0.150746
#   Name: 1066, dtype: object, Class_enc            0
#   x             0.510487
#   y             0.253731
#   width        0.0377517
#   height        0.164179
#   Name: 1067, dtype: object, Class_enc           0
#   x            0.536493
#   y            0.279851
#   width        0.034396
#   height       0.168657
#   Name: 1068, dtype: object], 'BET/img_07581.jpg': [Class_enc           1
#   x            0.495906
#   y            0.275729
#   width        0.323985
#   height       0.176571
#   Name: 2804, dtype: object], 'YFT/img_06404.jpg': [Class_enc           6
#   x            0.427471
#   y            0.539196
#   width        0.211104
#   height       0.251212
#   Name: 4213, dtype: object], 'ALB/img_04852.jpg': [Class_enc           0
#   x            0.291016
#   y            0.369333
#   width        0.128906
#   height       0.170667
#   Name: 1526, dtype: object], 'YFT/img_00739.jpg': [Class_enc            6
#   x             0.405064
#   y            0.0976472
#   width         0.125755
#   height        0.168705
#   Name: 3648, dtype: object, Class_enc            6
#   x              0.84256
#   y             0.110942
#   width         0.117151
#   height       0.0889369
#   Name: 3649, dtype: object], 'ALB/img_07048.jpg': [Class_enc            0
#   x             0.331392
#   y             0.591374
#   width         0.148506
#   height       0.0831663
#   Name: 2186, dtype: object], 'LAG/img_04435.jpg': [Class_enc           3
#   x            0.650354
#   y            0.474699
#   width         0.13125
#   height       0.152994
#   Name: 2996, dtype: object, Class_enc            3
#   x             0.766278
#   y             0.523602
#   width        0.0935252
#   height        0.193513
#   Name: 2997, dtype: object], 'OTHER/img_07547.jpg': [Class_enc           4
#   x            0.370761
#   y            0.611276
#   width        0.100992
#   height       0.114571
#   Name: 3364, dtype: object], 'ALB/img_01478.jpg': [Class_enc           0
#   x            0.719141
#   y            0.378472
#   width        0.238281
#   height       0.240278
#   Name: 509, dtype: object, Class_enc           0
#   x            0.562109
#   y            0.185417
#   width        0.261719
#   height         0.1625
#   Name: 510, dtype: object, Class_enc           0
#   x            0.226953
#   y            0.376389
#   width        0.207031
#   height       0.183333
#   Name: 511, dtype: object], 'LAG/img_07269.jpg': [Class_enc           3
#   x            0.617935
#   y            0.448851
#   width          0.2904
#   height       0.449201
#   Name: 3036, dtype: object, Class_enc           3
#   x            0.676093
#   y            0.836575
#   width        0.281755
#   height       0.306686
#   Name: 3037, dtype: object], 'ALB/img_02036.jpg': [Class_enc           0
#   x            0.260937
#   y             0.64375
#   width        0.126562
#   height       0.109722
#   Name: 710, dtype: object], 'ALB/img_01374.jpg': [Class_enc           0
#   x            0.870703
#   y            0.397222
#   width        0.174219
#   height       0.166667
#   Name: 477, dtype: object, Class_enc           0
#   x            0.614844
#   y            0.259722
#   width        0.129688
#   height       0.108333
#   Name: 478, dtype: object, Class_enc           0
#   x            0.197266
#   y            0.645833
#   width        0.238281
#   height       0.294444
#   Name: 479, dtype: object], 'ALB/img_04920.jpg': [Class_enc            0
#   x             0.524609
#   y             0.770139
#   width        0.0960938
#   height        0.218056
#   Name: 1557, dtype: object], 'ALB/img_07720.jpg': [Class_enc           0
#   x            0.606384
#   y            0.377786
#   width        0.241957
#   height       0.229323
#   Name: 2429, dtype: object, Class_enc           0
#   x            0.640869
#   y            0.177294
#   width        0.304963
#   height       0.143824
#   Name: 2430, dtype: object, Class_enc           0
#   x             0.33833
#   y            0.150783
#   width        0.241957
#   height        0.12394
#   Name: 2431, dtype: object, Class_enc           0
#   x            0.363495
#   y            0.292618
#   width        0.228163
#   height       0.137196
#   Name: 2432, dtype: object], 'OTHER/img_04238.jpg': [Class_enc            4
#   x             0.400233
#   y             0.617913
#   width        0.0915604
#   height        0.112475
#   Name: 3206, dtype: object], 'SHARK/img_01780.jpg': [Class_enc            5
#   x             0.467578
#   y             0.601389
#   width        0.0335937
#   height        0.202778
#   Name: 3414, dtype: object], 'ALB/img_02047.jpg': [Class_enc           0
#   x            0.528906
#   y            0.336111
#   width        0.271875
#   height       0.155556
#   Name: 713, dtype: object], 'ALB/img_07396.jpg': [Class_enc           0
#   x            0.194973
#   y            0.543606
#   width        0.119307
#   height       0.078768
#   Name: 2310, dtype: object], 'BET/img_00888.jpg': [Class_enc           1
#   x            0.220149
#   y            0.496303
#   width        0.106965
#   height       0.293356
#   Name: 2547, dtype: object], 'YFT/img_07510.jpg': [Class_enc           6
#   x            0.614195
#   y             0.57524
#   width        0.239916
#   height       0.154368
#   Name: 4324, dtype: object], 'YFT/img_02713.jpg': [Class_enc            6
#   x            0.0800643
#   y             0.486052
#   width         0.149047
#   height         0.19669
#   Name: 3856, dtype: object], 'ALB/img_02273.jpg': [Class_enc           0
#   x            0.869531
#   y            0.399306
#   width        0.179688
#   height       0.195833
#   Name: 768, dtype: object], 'DOL/img_04283.jpg': [Class_enc           2
#   x            0.325373
#   y            0.558993
#   width        0.334019
#   height       0.187113
#   Name: 2887, dtype: object], 'ALB/img_06393.jpg': [Class_enc           0
#   x            0.461328
#   y            0.273611
#   width        0.307031
#   height       0.202778
#   Name: 1982, dtype: object, Class_enc           0
#   x            0.164062
#   y            0.222222
#   width          0.1375
#   height       0.236111
#   Name: 1983, dtype: object], 'YFT/img_05184.jpg': [Class_enc           6
#   x            0.529145
#   y             0.64041
#   width        0.346853
#   height       0.270144
#   Name: 4110, dtype: object], 'ALB/img_05101.jpg': [Class_enc            0
#   x             0.220218
#   y             0.279104
#   width        0.0897651
#   height        0.298507
#   Name: 1611, dtype: object], 'YFT/img_00501.jpg': [Class_enc           6
#   x            0.666171
#   y            0.482723
#   width        0.387855
#   height       0.397122
#   Name: 3626, dtype: object, Class_enc           6
#   x            0.560272
#   y            0.217093
#   width        0.211136
#   height       0.218858
#   Name: 3627, dtype: object], 'YFT/img_03911.jpg': [Class_enc           6
#   x            0.456006
#   y            0.779851
#   width        0.474291
#   height       0.253397
#   Name: 3976, dtype: object], 'ALB/img_04683.jpg': [Class_enc            0
#   x             0.509766
#   y             0.596528
#   width        0.0851563
#   height        0.234722
#   Name: 1481, dtype: object], 'BET/img_01725.jpg': [Class_enc           1
#   x            0.607071
#   y             0.48411
#   width        0.139804
#   height       0.349194
#   Name: 2579, dtype: object], 'BET/img_00435.jpg': [Class_enc           1
#   x            0.762308
#   y            0.499197
#   width        0.237942
#   height         0.1512
#   Name: 2525, dtype: object, Class_enc           1
#   x            0.499215
#   y            0.364764
#   width        0.306776
#   height       0.209445
#   Name: 2526, dtype: object, Class_enc           1
#   x            0.336064
#   y            0.449777
#   width        0.203525
#   height       0.244156
#   Name: 2527, dtype: object], 'DOL/img_02798.jpg': [Class_enc           2
#   x            0.423811
#   y            0.668505
#   width        0.148147
#   height       0.153377
#   Name: 2872, dtype: object], 'ALB/img_00020.jpg': [Class_enc           0
#   x             0.50625
#   y            0.872222
#   width        0.096875
#   height       0.252778
#   Name: 9, dtype: object, Class_enc           0
#   x            0.600391
#   y            0.792361
#   width        0.122656
#   height       0.323611
#   Name: 10, dtype: object, Class_enc           0
#   x            0.535156
#   y            0.597917
#   width        0.110938
#   height       0.148611
#   Name: 11, dtype: object, Class_enc           0
#   x            0.601562
#   y            0.622917
#   width        0.071875
#   height       0.245833
#   Name: 12, dtype: object, Class_enc            0
#   x             0.541406
#   y              0.53125
#   width        0.0984375
#   height        0.154167
#   Name: 13, dtype: object], 'ALB/img_05077.jpg': [Class_enc           0
#   x             0.24245
#   y             0.19403
#   width        0.120805
#   height       0.244776
#   Name: 1602, dtype: object], 'DOL/img_01042.jpg': [Class_enc           2
#   x            0.323212
#   y            0.627693
#   width        0.181942
#   height        0.12505
#   Name: 2833, dtype: object], 'ALB/img_02342.jpg': [Class_enc           0
#   x            0.727734
#   y            0.925333
#   width        0.446094
#   height       0.138667
#   Name: 783, dtype: object], 'SHARK/img_00265.jpg': [Class_enc           5
#   x            0.533594
#   y            0.676078
#   width        0.495313
#   height       0.191992
# ...
#   y              0.45295
#   width        0.0775498
#   height        0.114423
#   Name: 2261, dtype: object], 'OTHER/img_03772.jpg': [Class_enc            4
#   x             0.623043
#   y             0.535128
#   width        0.0671967
#   height        0.142515
#   Name: 3188, dtype: object], 'OTHER/img_00262.jpg': [Class_enc           4
#   x            0.797912
#   y            0.392614
#   width        0.295901
#   height       0.203992
#   Name: 3055, dtype: object], 'ALB/img_05851.jpg': [Class_enc           0
#   x            0.220703
#   y            0.305955
#   width        0.208594
#   height       0.110883
#   Name: 1844, dtype: object], 'ALB/img_07008.jpg': [Class_enc           0
#   x            0.483594
#   y            0.641667
#   width        0.059375
#   height       0.155556
#   Name: 2164, dtype: object], 'ALB/img_02737.jpg': [Class_enc           0
#   x             0.24375
#   y            0.519333
#   width        0.134375
#   height          0.124
#   Name: 906, dtype: object], 'YFT/img_06364.jpg': [Class_enc           6
#   x            0.250443
#   y            0.586584
#   width        0.139628
#   height       0.121158
#   Name: 4210, dtype: object], 'ALB/img_05375.jpg': [Class_enc           0
#   x            0.662891
#   y            0.188194
#   width        0.232031
#   height         0.1875
#   Name: 1706, dtype: object, Class_enc           0
#   x            0.753516
#   y              0.5875
#   width        0.271094
#   height       0.261111
#   Name: 1707, dtype: object, Class_enc           0
#   x            0.430469
#   y             0.16875
#   width        0.278125
#   height       0.156944
#   Name: 1708, dtype: object, Class_enc           0
#   x            0.369922
#   y            0.331944
#   width        0.263281
#   height       0.294444
#   Name: 1709, dtype: object], 'YFT/img_03590.jpg': [Class_enc           6
#   x            0.267897
#   y            0.633865
#   width          0.1834
#   height       0.136919
#   Name: 3952, dtype: object], 'ALB/img_00037.jpg': [Class_enc           0
#   x            0.263281
#   y               0.476
#   width        0.071875
#   height       0.210667
#   Name: 17, dtype: object], 'YFT/img_07067.jpg': [Class_enc           6
#   x            0.695091
#   y            0.716115
#   width        0.108045
#   height       0.313239
#   Name: 4280, dtype: object], 'YFT/img_05662.jpg': [Class_enc           6
#   x            0.234375
#   y            0.591509
#   width        0.147385
#   height       0.129039
#   Name: 4148, dtype: object], 'ALB/img_01446.jpg': [Class_enc           0
#   x            0.335547
#   y            0.164583
#   width        0.253906
#   height       0.165278
#   Name: 499, dtype: object, Class_enc           0
#   x            0.814844
#   y            0.413889
#   width        0.192188
#   height       0.180556
#   Name: 500, dtype: object], 'ALB/img_01357.jpg': [Class_enc           0
#   x            0.334766
#   y              0.1625
#   width        0.257031
#   height       0.152778
#   Name: 464, dtype: object, Class_enc           0
#   x            0.557031
#   y            0.310417
#   width        0.185938
#   height       0.179167
#   Name: 465, dtype: object], 'BET/img_07518.jpg': [Class_enc           1
#   x            0.574172
#   y            0.268336
#   width        0.364028
#   height       0.162654
#   Name: 2798, dtype: object], 'ALB/img_02825.jpg': [Class_enc            0
#   x             0.473828
#   y             0.608333
#   width        0.0492188
#   height        0.222222
#   Name: 927, dtype: object], 'OTHER/img_04448.jpg': [Class_enc            4
#   x             0.638369
#   y             0.553292
#   width        0.0766278
#   height        0.371656
#   Name: 3215, dtype: object], 'ALB/img_03698.jpg': [Class_enc            0
#   x              0.39375
#   y            0.0800866
#   width          0.19375
#   height        0.149351
#   Name: 1232, dtype: object], 'DOL/img_01311.jpg': [Class_enc            2
#   x             0.574905
#   y             0.519061
#   width        0.0675897
#   height        0.238922
#   Name: 2838, dtype: object], 'YFT/img_07368.jpg': [Class_enc           6
#   x            0.231882
#   y            0.585106
#   width        0.157912
#   height       0.145784
#   Name: 4310, dtype: object], 'OTHER/img_00126.jpg': [Class_enc           4
#   x            0.625391
#   y            0.169333
#   width        0.272656
#   height          0.328
#   Name: 3048, dtype: object], 'ALB/img_06722.jpg': [Class_enc           0
#   x               0.175
#   y            0.602083
#   width        0.107813
#   height       0.104167
#   Name: 2092, dtype: object], 'YFT/img_03185.jpg': [Class_enc           6
#   x            0.579012
#   y            0.635677
#   width        0.255984
#   height       0.301455
#   Name: 3910, dtype: object], 'ALB/img_05089.jpg': [Class_enc           0
#   x            0.547266
#   y            0.541667
#   width        0.110156
#   height       0.161111
#   Name: 1606, dtype: object], 'BET/img_05164.jpg': [Class_enc           1
#   x            0.619675
#   y            0.327993
#   width        0.269712
#   height       0.293576
#   Name: 2718, dtype: object], 'OTHER/img_00305.jpg': [Class_enc            4
#   x             0.363098
#   y             0.646905
#   width         0.175262
#   height       0.0558881
#   Name: 3058, dtype: object], 'OTHER/img_05092.jpg': [Class_enc           4
#   x            0.416737
#   y            0.587524
#   width        0.321837
#   height       0.241716
#   Name: 3256, dtype: object], 'ALB/img_04500.jpg': [Class_enc           0
#   x            0.284375
#   y            0.276181
#   width        0.126562
#   height        0.12731
#   Name: 1432, dtype: object], 'SHARK/img_07556.jpg': [Class_enc            5
#   x             0.472266
#   y             0.564583
#   width        0.0226563
#   height          0.1375
#   Name: 3567, dtype: object], 'YFT/img_06171.jpg': [Class_enc           6
#   x            0.580951
#   y            0.550847
#   width        0.180075
#   height       0.223543
#   Name: 4194, dtype: object], 'YFT/img_04573.jpg': [Class_enc           6
#   x            0.659907
#   y            0.595449
#   width        0.125222
#   height        0.18814
#   Name: 4047, dtype: object], 'YFT/img_01385.jpg': [Class_enc           6
#   x            0.264251
#   y            0.629217
#   width        0.141309
#   height       0.145317
#   Name: 3714, dtype: object], 'ALB/img_03382.jpg': [Class_enc           0
#   x            0.407031
#   y            0.651389
#   width        0.129688
#   height       0.163889
#   Name: 1116, dtype: object], 'OTHER/img_03191.jpg': [Class_enc            4
#   x             0.635225
#   y             0.551895
#   width        0.0829152
#   height        0.373053
#   Name: 3169, dtype: object], 'BET/img_05240.jpg': [Class_enc           1
#   x            0.622279
#   y            0.460053
#   width        0.177475
#   height       0.351674
#   Name: 2720, dtype: object], 'YFT/img_04255.jpg': [Class_enc           6
#   x            0.526928
#   y            0.647691
#   width        0.341312
#   height       0.280338
#   Name: 4009, dtype: object], 'ALB/img_00490.jpg': [Class_enc            0
#   x             0.674219
#   y             0.472222
#   width        0.0609375
#   height           0.125
#   Name: 153, dtype: object], 'ALB/img_04100.jpg': [Class_enc           0
#   x            0.385156
#   y            0.101333
#   width        0.096875
#   height       0.181333
#   Name: 1349, dtype: object], 'YFT/img_04632.jpg': [Class_enc           6
#   x            0.349069
#   y            0.420872
#   width        0.103059
#   height       0.190776
#   Name: 4053, dtype: object], 'YFT/img_06094.jpg': [Class_enc           6
#   x            0.262079
#   y            0.540898
#   width        0.221631
#   height       0.177778
#   Name: 4183, dtype: object], 'ALB/img_04259.jpg': [Class_enc           0
#   x             0.69375
#   y               0.854
#   width        0.434375
#   height          0.268
#   Name: 1371, dtype: object], 'ALB/img_00998.jpg': [Class_enc           0
#   x            0.479297
#   y            0.499333
#   width        0.153906
#   height       0.345333
#   Name: 305, dtype: object], 'YFT/img_03560.jpg': [Class_enc           6
#   x            0.619182
#   y            0.487096
#   width        0.397274
#   height       0.410757
#   Name: 3948, dtype: object], 'DOL/img_05444.jpg': [Class_enc           2
#   x            0.485506
#   y            0.836575
#   width        0.124569
#   height       0.259181
#   Name: 2902, dtype: object], 'ALB/img_01507.jpg': [Class_enc           0
#   x            0.357031
#   y            0.345139
#   width        0.176563
#   height       0.304167
#   Name: 519, dtype: object], 'ALB/img_00201.jpg': [Class_enc            0
#   x               0.5625
#   y             0.523881
#   width         0.106544
#   height       0.0567164
#   Name: 51, dtype: object], 'ALB/img_06826.jpg': [Class_enc           0
#   x            0.379688
#   y            0.595833
#   width        0.135938
#   height       0.122222
#   Name: 2110, dtype: object, Class_enc            0
#   x             0.148438
#   y             0.613889
#   width         0.090625
#   height       0.0861111
#   Name: 2111, dtype: object, Class_enc           0
#   x            0.108594
#   y            0.779167
#   width        0.065625
#   height       0.244444
#   Name: 2112, dtype: object], 'DOL/img_06644.jpg': [Class_enc           2
#   x             0.37164
#   y            0.637748
#   width        0.188633
#   height       0.116489
#   Name: 2929, dtype: object], 'ALB/img_05803.jpg': [Class_enc            0
#   x             0.382422
#   y             0.134199
#   width         0.174219
#   height       0.0952381
#   Name: 1817, dtype: object], 'ALB/img_02762.jpg': [Class_enc           0
#   x            0.799219
#   y            0.407639
#   width        0.176563
#   height       0.176389
#   Name: 907, dtype: object], 'ALB/img_00712.jpg': [Class_enc            0
#   x             0.465234
#   y             0.617361
#   width        0.0445313
#   height        0.204167
#   Name: 220, dtype: object], 'ALB/img_03041.jpg': [Class_enc           0
#   x            0.482813
#   y            0.775667
#   width        0.264063
#   height       0.167351
#   Name: 1001, dtype: object], 'BET/img_04179.jpg': [Class_enc           1
#   x            0.352114
#   y            0.360939
#   width        0.258791
#   height       0.265336
#   Name: 2678, dtype: object, Class_enc           1
#   x            0.600481
#   y            0.247098
#   width        0.278316
#   height       0.238861
#   Name: 2679, dtype: object], 'ALB/img_01458.jpg': [Class_enc           0
#   x            0.739844
#   y            0.889333
#   width         0.31875
#   height          0.216
#   Name: 504, dtype: object], 'ALB/img_05353.jpg': [Class_enc           0
#   x            0.594531
#   y             0.45625
#   width        0.101562
#   height       0.220833
#   Name: 1701, dtype: object], 'DOL/img_05367.jpg': [Class_enc            2
#   x               0.5808
#   y             0.445708
#   width        0.0675897
#   height        0.128543
#   Name: 2900, dtype: object], 'ALB/img_01514.jpg': [Class_enc            0
#   x             0.498742
#   y             0.782836
#   width        0.0713087
#   height       0.0940299
#   Name: 521, dtype: object], 'ALB/img_01941.jpg': [Class_enc           0
#   x            0.540625
#   y            0.186147
#   width         0.19375
#   height       0.158009
#   Name: 679, dtype: object], 'SHARK/img_02169.jpg': [Class_enc           5
#   x            0.509766
#   y            0.399333
#   width        0.402344
#   height       0.265333
#   Name: 3430, dtype: object], 'ALB/img_00215.jpg': [Class_enc            0
#   x             0.429859
#   y             0.367688
#   width        0.0603448
#   height        0.194986
#   Name: 63, dtype: object], 'ALB/img_05204.jpg': [Class_enc            0
#   x             0.467085
#   y             0.908078
#   width        0.0924765
#   height        0.167131
#   Name: 1647, dtype: object], 'LAG/img_04352.jpg': [Class_enc           3
#   x            0.602609
#   y             0.57914
#   width        0.134786
#   height       0.202594
#   Name: 2992, dtype: object, Class_enc            3
#   x             0.772566
#   y             0.485877
#   width        0.0927393
#   height        0.154391
#   Name: 2993, dtype: object], 'SHARK/img_06444.jpg': [Class_enc           5
#   x            0.531641
#   y               0.398
#   width        0.433594
#   height       0.206667
#   Name: 3533, dtype: object], 'YFT/img_03081.jpg': [Class_enc           6
#   x            0.640514
#   y            0.485619
#   width        0.373449
#   height       0.411742
#   Name: 3897, dtype: object], 'ALB/img_06420.jpg': [Class_enc           0
#   x            0.436719
#   y            0.165278
#   width        0.290625
#   height       0.163889
#   Name: 1988, dtype: object, Class_enc           0
#   x             0.65625
#   y            0.213889
#   width        0.270313
#   height       0.211111
#   Name: 1989, dtype: object, Class_enc           0
#   x            0.756641
#   y            0.568056
#   width        0.249219
#   height       0.252778
#   Name: 1990, dtype: object, Class_enc           0
#   x            0.365625
#   y            0.358333
#   width        0.290625
#   height       0.363889
#   Name: 1991, dtype: object], 'BET/img_03453.jpg': [Class_enc            1
#   x             0.448416
#   y             0.589211
#   width        0.0628776
#   height        0.261806
#   Name: 2655, dtype: object], 'YFT/img_07571.jpg': [Class_enc           6
#   x             0.40143
#   y            0.552246
#   width         0.25543
#   height        0.28747
#   Name: 4333, dtype: object], 'BET/img_06997.jpg': [Class_enc            1
#   x             0.450568
#   y             0.586269
#   width        0.0618848
#   height        0.265336
#   Name: 2780, dtype: object], 'ALB/img_07136.jpg': [Class_enc           0
#   x            0.442222
#   y            0.472876
#   width        0.183671
#   height       0.266311
#   Name: 2219, dtype: object], 'ALB/img_00632.jpg': [Class_enc           0
#   x            0.244966
#   y            0.204478
#   width        0.134228
#   height       0.250746
#   Name: 196, dtype: object], 'ALB/img_03737.jpg': [Class_enc           0
#   x            0.357031
#   y            0.682639
#   width        0.123438
#   height       0.104167
#   Name: 1246, dtype: object], 'ALB/img_02148.jpg': [Class_enc           0
#   x            0.651172
#   y            0.199306
#   width        0.278906
#   height       0.176389
#   Name: 735, dtype: object, Class_enc           0
#   x            0.899219
#   y            0.352083
#   width        0.103125
#   height       0.331944
#   Name: 736, dtype: object, Class_enc           0
#   x            0.363672
#   y            0.238889
#   width        0.227344
#   height       0.197222
#   Name: 737, dtype: object, Class_enc           0
#   x            0.218359
#   y            0.207639
#   width        0.144531
#   height       0.190278
#   Name: 738, dtype: object], 'ALB/img_07035.jpg': [Class_enc           0
#   x             0.36873
#   y            0.666435
#   width        0.107367
#   height       0.174095
#   Name: 2180, dtype: object], 'ALB/img_07447.jpg': [Class_enc            0
#   x             0.177833
#   y             0.592527
#   width        0.0954406
#   height        0.102068
#   Name: 2334, dtype: object], 'YFT/img_02111.jpg': [Class_enc           6
#   x            0.696121
#   y             0.72482
#   width        0.096302
#   height       0.317697
#   Name: 3793, dtype: object], 'ALB/img_00191.jpg': [Class_enc            0
#   x             0.443359
#   y             0.619444
#   width        0.0726563
#   height        0.155556
#   Name: 47, dtype: object, Class_enc            0
#   x             0.117969
#   y             0.765278
#   width        0.0703125
#   height        0.302778
#   Name: 48, dtype: object], 'ALB/img_05272.jpg': [Class_enc            0
#   x             0.445703
#   y             0.615278
#   width        0.0742188
#   height        0.216667
#   Name: 1675, dtype: object], 'YFT/img_01492.jpg': [Class_enc           6
#   x            0.187309
#   y            0.534202
#   width        0.220402
#   height       0.172969
#   Name: 3724, dtype: object, Class_enc           6
#   x            0.456193
#   y            0.215622
#   width        0.396791
#   height       0.274749
#   Name: 3725, dtype: object], 'ALB/img_04528.jpg': [Class_enc            0
#   x             0.188672
#   y             0.538667
#   width        0.0476563
#   height        0.205333
#   Name: 1443, dtype: object], ...}

# %%
#conv_faster = convert_faster(data2)
#conv_faster = conv_faster.astype('int64')
#faster_dict = to_dict(conv_faster, short_names)
new_faster = iter_dict(faster_dict)

# %% [raw]
# conv.to_csv('/home/w/DS_Projects/Kaggle/Nature Conservancy/Scripts/BoundingBoxes_Liu Weijie/darknet_annots.txt',
#             header = False, index = False, sep=' ', mode='a')
#
# conv_faster.to_csv('/home/w/DS_Projects/Kaggle/Nature Conservancy/Scripts/BoundingBoxes_Liu Weijie/faster_rcnn_annots.txt',
#             header = False, index = False, sep=' ', mode='a')

# %%
def iter_dict(dictionary):

    new_dict = {}
    
    for key, value in dictionary.items():
        lines = []
        for i in value:
            line = []
            for j in i:
                line.append(j)
            lines.append(line)
            
        new_dict[key] = lines
            
    return new_dict

# %% [raw]
# def writeDict(dict, net, txt = True):
#
#     os.chdir('/home/w/DS_Projects/Kaggle/Nature Conservancy/Scripts/BoundingBoxes_Liu Weijie/')
#     if 'labels_{}'.format(net) not in os.listdir():
#         os.mkdir('labels_{}'.format(net))
#         os.chdir('labels_{}'.format(net))
#         for i in labels:
#             os.mkdir(i)
#
#     for key, value in dict.items():
#         name = key.replace('.jpg', '')
#         if txt:
#             with open('{}.txt'.format(name), "a") as f:
#                 for i in value:
#                     f.write(" ".join([str(a) for a in i]) + '\n')
#         else:
#             with open('{}'.format(name), "a") as f:
#                 for i in value:
#                     f.write(" ".join([str(a) for a in i]) + '\n')
#
#
# writeDict(new, 'yolo PROPER?')
# writeDict(new_faster, 'faster_rcnn')

# %%
def save_testnames():
    
    test_names = os.listdir('/home/w/DS_Projects/Kaggle/Nature Conservancy/test_stg1/test_stg1/')
    path = '/home/w/DS_Projects/Kaggle/Nature Conservancy/Scripts/BoundingBoxes_Liu Weijie/'

    full_test = []
    for i in test_names:
        j = path + i
        full_test.append(j)

    with open(path + '2017_test.txt', "a+") as myfile:
        for line in full_test:
            myfile.write(line + '\n')
            
    return

save_testnames()
